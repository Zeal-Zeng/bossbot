# %%
RESUME_DIR = '/home/zengzheng.zeal/jianli/new'
BACKUP_DIR = '/home/zengzheng.zeal/jianli/bak'
def add_code(ejid,code):
    import sqlite3
    conn = sqlite3.connect(RESUME_DIR+'/boss_jid_code.db')
    c= conn.cursor()
    c.execute(" insert into boss_ejid_code VALUES( '%s','%s' )"%(ejid,code))
    conn.commit()
    conn.close()
def code_dict():
    import sqlite3
    conn = sqlite3.connect(RESUME_DIR+'/boss_jid_code.db')
    c= conn.cursor()
    c.execute("select ejid,code from boss_ejid_code")
    res = dict(c.fetchall())
    conn.close()
    return res
def init_table():
    import sqlite3
    conn = sqlite3.connect(RESUME_DIR+'/boss_jid_code.db')
    c= conn.cursor()
    c.execute("create table boss_ejid_code(ejid string,code string) ")
    conn.commit()
    conn.close()

from bossbot import BossBot
import time,random

# %%
codes = code_dict()
GREET_MSG="""你好，可以发一份简历过来吗，我这里是内推，也可以直接通过这个链接投简历哦 https://job.toutiao.com/s/NULgJjt """
class Bot(BossBot):
    
    def check_info_and_first_greet(self,uid,greet_msg):
        '''
        获取达人信息 如果是没聊过就发消息
        '''
        info  = self.geek_info(uid)
        if info and not info['bothTalked'] and info['edu'] in('博士','硕士','本科') and info['note']!='已聊':
            # 第一次打招呼
            self.send_message(uid, greet_msg)
            self.exchange_request(uid)
            self.change_note(info, '已聊')
            return True,info
        return False,info
    

    def on_text_message(self, data, uid, msg):
        '''
        文本 消息回调函数。
        :param data: 收到的完整消息内容
        :param uid: 发送次消息的boss的id
        :param msg: 文本内容
        :return:
        '''
        is_greet,info = self.check_info_and_first_greet(uid,GREET_MSG)
        print('收到文字消息:' + msg)
    
    def on_connect(self, client, userdata, flags, rc):
        '''
        websocket连接成功回调函数。
        :param client: 
        :param userdata: 
        :param flags: 
        :param rc: 
        :return: 
        '''
        print("websocket 连接成功！")
    
    def download_resume(self,info):
        '''
        下载简历
        '''
        if 'toPositionId' not in info:
            print(info)
        if info['toPositionId'] not in codes:
            print('-------=-=-=-',info['toPositionId'],info['toPosition'])
            return 
        job_code=codes.get(info['toPositionId'])
        filename_jobcode = '【'+job_code+'】' if job_code  else ''
        print("简历下载开始 job_code:",filename_jobcode)
        
        PATH=RESUME_DIR+'/'
        if 'encryptUid' not in info:
            return 
        url='https://docdownload.zhipin.com/wflow/zpgeek/download/download4boss/'+info['encryptUid']
        r=self.session.get(url)
        print(r.headers)
        
        import urllib
        
        if not r.headers.get('Content-Disposition'):
            return
        filename_info = [i.strip().split('=',1) for i in  urllib.parse.unquote(r.headers['Content-Disposition'].encode('ISO-8859-1').decode('utf8')).split(';')]
        filename_org = [i[1] for i in filename_info if i[0]=='filename'][0].replace('"','').replace('/','')
        filename_f = filename_org.split('.',1)
        filename = filename_f[0]+filename_jobcode+'.'+filename_f[1]
        fo = open(PATH+filename,'wb')
        fo.write(r.content)
        fo.close()
        print("简历下载完成 ",r.headers['Content-Disposition'],filename)
        self.change_note(info, '简历已下载')
    
    
    def deal_history_chat_and_donwload(self):
        import time 
        friends=list(self.friends.keys())
        for uid in friends:
            time.sleep(0.4)
            is_greet,info = self.check_info_and_first_greet(uid,GREET_MSG)
            
            if info and info['bothTalked'] and info['edu'] in('博士','硕士','本科') and info['note']!='简历已下载':
                r=self.get_his_msg(uid)
                for msg in r.json()['zpData']['messages'][-3:]:
                    if msg['body']['type']==7:
                        self.exchange_accept(msg['mid'],msg['from']['uid'])
                        print('0------',info.get('resumeVisible','-=-='))

            if info and info['edu'] in('博士','硕士','本科') and info['resumeVisible']==1 and info['note']!='简历已下载' : 
                self.download_resume(info)
                    
    def download_all_reusme(self):
        friends=list(self.friends.keys())
        for uid in friends:
            info = self.geek_info(uid)
            if info['resumeVisible']==1 and info['note']!='简历已下载' :
                self.download_resume(info)


    def _sayhello(self,info):
        time.sleep(0.5+(random.randint(3,9)/10))
        start_chat_param={
        'gid': info['encryptGeekId'] , 
        # 'suid':'',
        'jid':  info['geekCard']['encryptJobId'] ,
        'expectId': info['geekCard']['expectId'],  
        'lid':  info['geekCard']['lid'] , 
        # 'from': '',
        'securityId':info['geekCard']['securityId'] 
            }

        rrr = bot.session.post('https://www.zhipin.com/wapi/zpjob/chat/start?_=%d'%int(time.time() * 1000)
                         ,data=start_chat_param
                        )
        print(rrr.text)
    
    
    def sayhello_newgeek(self,n):
        '''
        打招呼 - 新人
        '''
        get_geek_params ={
            "age": "16,-1",
            "gender": 0,
            "exchangeResumeWithColleague": 0,
            "switchJobFrequency": 0,
            "activation": 0,
            "recentNotView": 0,
            "school": "1104,1103,1102,1105,1106",
            "experience": 0,
            "degree": "203,204,205",
            "salary": 0,
            "intention": 0,
            "jobid": -1,
            "page": 1,
            "tag": 1,
            "status": 1,
            "coverScreenMemory": 1,
               '_': int(time.time() * 1000)
        }
        rr=self.session.get('https://www.zhipin.com/wapi/zprelation/interaction/bossGetGeek',params=get_geek_params)
        infos = rr.json()['zpData']['geekList']
        for i in range(n):
            info=infos[i]
            self._sayhello(info)
    
    def sayhello_randjob(self,n):
        '''
        打招呼 - 按不同职位
        '''
        jobs=self.get_jobs()
        import random 
        list_params={
            'age': '16,-1',
            'gender': 0,
            'exchangeResumeWithColleague': 0,
            'switchJobFrequency': 0,
            'activation': 0,
            'recentNotView': 0,
            "school": "1104,1103,1102,1105,1106",
            'major': 0,
            'experience': 0,
            "degree": "203,204,205",
            'salary': 0,
            'intention': 0,
            'jobId': jobs[random.randint(0,len(jobs)-1)][0],
            'page': 1,
            'coverScreenMemory': 0,
            '_': int(time.time() * 1000)
        }
        rr=self.session.get("https://www.zhipin.com/wapi/zpjob/rec/geek/list",params=list_params)
        infos = rr.json()['zpData']['geekList']
        for i in range(n):
            info=infos[i]
            self._sayhello(info)
            
    def post_job(self,zijie_job_code,job_name,desc,city):
        city_map={
            '北京':'[{"addressText":"北京海淀区中航广场1号楼--","encRelationId":"38bf4f2309a2d2820XV73Nq1FVQ~"}]',
            '上海':'[{"addressText":"上海徐汇区漕河泾中心C栋--","encRelationId":"3293bff1d67aefab0nV_3NS9EVs~"}]',
            '深圳':'[{"addressText":"TANGJ(太子广场店)广东省深圳市南山区蛇口街道太子路51号太子广场6楼","encRelationId":"4c78ee27367751cb0H1839q6GVs~"}]',
            '重庆':'[{"addressText":"IFS国金中心6重庆江北区江北嘴庆云路1号国金中心6号办公楼","encRelationId":"28f39e75d91b26300H1839W9ElA~"}]',
            '成都':'[{"addressText":"OCG国际中心A座四川省成都市高新区天府四街158号OCG国际中心","encRelationId":"18dc039f4e68631a0H1839q4EFo~"}]',
            '武汉':'[{"addressText":"光谷新发展国际中心B座湖北省武汉市洪山区关山大道473号光谷新发展国际中心B座10-16F","encRelationId":"3d51d11c84de58f233Vy39S_FlM~"}]',
            '青岛':'[{"addressText":"北京航空航天大学青岛研究院山东省青岛市崂山区松岭路393号北京航空航天大学青岛研究院4号楼3层&4层","encRelationId":"7f16429f0a9ecef533Vy39S8FlY~"}]'
        }
        import time 
        eidt_url='https://www.zhipin.com/wapi/zpjob/job/edit?hasProxy=1&_=%d'%int(time.time() * 1000)
        edit_flag = self.session.get(eidt_url).json()['zpData']['editFlag']
        predict_url='https://www.zhipin.com/wapi/zpjob/job/position/predict?_=%d'%int(time.time() * 1000)
        para={
            'jobName':job_name,
            'jobDesc':desc,
            'jobType':0,
            'editFlag':edit_flag,
        }
        r = self.session.post(predict_url, data=para)
        code = r.json().get('zpData',{}).get('recommendPosition',{}).get('config',{}).get('code')
        if not code:
            print('没有code')
            return
        name = r.json()['zpData']['recommendPosition']['config']['name']
        print('name code ',name,code)
        save_url='https://www.zhipin.com/wapi/zpjob/job/save?_=%d'%int(time.time() * 1000)
        para={
        'comId': '',
        'brandId': '',
        'positionName': job_name,
        'positionCategory': name,
        'position': code,
        'degree': 203,
        'skill[]': name,
        'skill[]': 'Python',

        'jobType': 0,
        'experience': 101,
        'lowSalary': 25,
        'highSalary': 50,
        'salaryMonth': 15,
        'leastMonth': 3,
        'daysPerWeek': '',
        'performance': '',
        'description': desc,
        'department': '',
        'reportObject': '',
        'graduateYear': '',
        'recruitEndTime': '',
        'anonymous': 0,
        'requireIndustries': '',
        'requireIndustriesDesc': '',
        'trainingPlan': '',
        'workday': 0,
        'salaryType': 0,
        'acType': 2501,
        'periodType': 2,
        'period': '',
        'deadline': '',
        'basicSalary': 0,
        'highBasicSalary': 0,
        'salaryDay': 0,
        'socialInsuranceType': 0,
        'other': '',
        'createType': 0,
        'probation': '',
        'socialInsuranceTypeName': '',
        'preferenceJsonStr': '',
        'knowBlueIntermediaryTip': 0,
        'proxyType': 0,
        'performanceExplain': '',
        'relationIdJson': city_map[city],
        'phoneAssistantStatus': 0,
        'proxySelfFlag': True,
        'mustAnonymous': False,
        'workType': 0,
        'workArea': '',
        'needProxyCom': False,
        'spreadCity': '',
        'editFlag': edit_flag
        }
        r = self.session.post(save_url, data=para)
        job_id = r.json().get('zpData',{}).get('jobId')
        add_code(job_id,zijie_job_code)
        print('name code ',job_name,zijie_job_code,r.json())

# %%
uid= '31964291'
token='8hUoen2wwc698GH'
wt2='DBuN4ywCL5PtAsnoEACWsNbuLiivIW4umsxVpOw5-yUJzeaQw8y2pv0Cpqv061tokT9sYrgC1POG-iUowVp_PUw~~'

bot = Bot()
bot.login(uid= uid,user_id=wt2,token=token)

# %%
bot.start()
# Out:
# websocket 连接成功！

# %%
bot.get_chats()
bot.deal_history_chat_and_donwload()
# Out:
# 简历下载开始 job_code: 【E0703】
# {'Date': 'Wed, 03 Jan 2024 02:33:31 GMT', 'Content-Type': 'application/pdf;charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'content-disposition': 'attachment; filename="%E3%80%90%E3%80%90%E6%8A%96%E9%9F%B3%E7%9B%B4%E6%92%AD%E3%80%91%E5%A4%A7%E6%95%B0%E6%8D%AE%E5%B7%A5%E7%A8%8B%E5%B8%88-%E6%95%B0%E6%8D%AE%E4%BB%93%E5%BA%93%E6%96%B9%E5%90%91_%E6%B7%B1%E5%9C%B3%E3%80%91%E5%BE%90%E6%A2%A6%E4%BA%91%2023%E5%B9%B4%E5%BA%94%E5%B1%8A%E7%94%9F.pdf"; filename*=utf-8\'\'%E3%80%90%E3%80%90%E6%8A%96%E9%9F%B3%E7%9B%B4%E6%92%AD%E3%80%91%E5%A4%A7%E6%95%B0%E6%8D%AE%E5%B7%A5%E7%A8%8B%E5%B8%88-%E6%95%B0%E6%8D%AE%E4%BB%93%E5%BA%93%E6%96%B9%E5%90%91_%E6%B7%B1%E5%9C%B3%E3%80%91%E5%BE%90%E6%A2%A6%E4%BA%91%2023%E5%B9%B4%E5%BA%94%E5%B1%8A%E7%94%9F.pdf', 'x-envoy-upstream-service-time': '17', 'Cache-Control': 'no-cache'}
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [5], line 2
#       1 bot.get_chats()
# ----> 2 bot.deal_history_chat_and_donwload()
#
# Cell In [2], line 91, in Bot.deal_history_chat_and_donwload(self)
#      88             print('0------',info.get('resumeVisible','-=-='))
#      90 if info and info['edu'] in('博士','硕士','本科') and info['resumeVisible']==1 and info['note']!='简历已下载' :
# ---> 91     self.download_resume(info)
#
# Cell In [2], line 67, in Bot.download_resume(self, info)
#      65 filename_info = [i.strip().split('=',1) for i in  urllib.parse.unquote(r.headers['Content-Disposition'].encode('ISO-8859-1').decode('utf8')).split(';')]
#      66 filename_org = [i[1] for i in filename_info if i[0]=='filename'][0].replace('"','').replace('/','')
# ---> 67 filename_f = filename.split('.',1)
#      68 filename = filename_f[0]+filename_jobcode+'.'+filename_f[1]
#      69 fo = open(PATH+filename,'wb')
#
# UnboundLocalError: local variable 'filename' referenced before assignment

# %%
bot.sayhello_randjob(5)
bot.sayhello_randjob(5)
bot.sayhello_randjob(5)

# %%
bot.sayhello_newgeek(15)
# Out:
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x10842a570>
# receive:  {"type": 4, "iqResponse": {"qid": 0, "query": "/message/suggest", "results": [{"key": "friend_source", "value": "0"}, {"key": "suggestions", "value": "[]"}, {"key": "friendId", "value": "102488365"}, {"key": "msg_id", "value": "486301624553"}, {"key": "business_scene_type", "value": "1"}]}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x10842a570>
# receive:  {"type": 6, "messageRead": [{"userId": 102488365, "messageId": 486153834154, "readTime": 1694757492}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x10842a570>
# receive:  {"type": 6, "messageRead": [{"userId": 102488365, "messageId": 486301625492, "readTime": 1694757492}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x10842a570>
# receive:  {"type": 1, "messages": [{"from": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "", "headImg": 15, "certification": 0}, "to": {"uid": 102488365, "name": "孙伟", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20220907/607f1f3d68754fd010282d7e98ca8cc12901f56cccecc065b0b833dbce738f2323da15507e1ccc5d_s.jpg", "company": "", "headImg": 0, "certification": 0}, "type": 1, "mid": 486301632350, "time": 1694757493039, "body": {"type": 4, "templateId": 1, "action": {"aid": 41, "extend": "{\"resumeName\":\"个人简历-孙伟202308.pdf\",\"resumeId\":233623597,\"annexType\":0,\"resumeRevocable\":1}"}, "headTitle": ""}, "offline": false, "received": false, "taskId": 0, "cmid": 0, "status": 0, "uncount": 1, "pushSound": 0, "flag": 1}]}
# err geek_info 31964291 {'code': 0, 'message': 'Success', 'zpData': {'msg': '已在其他设备删除该好友，该会话已经关闭。', 'status': -1}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x109cfe5e0>
# receive:  {"type": 1, "messages": [{"from": {"uid": 102488365, "name": "孙伟", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20220907/607f1f3d68754fd010282d7e98ca8cc12901f56cccecc065b0b833dbce738f2323da15507e1ccc5d_s.jpg", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 3, "mid": 486301632308, "time": 1694757493043, "body": {"type": 4, "templateId": 1, "action": {"aid": 97, "extend": "{\"mid\":486301625000}"}, "headTitle": ""}, "offline": false, "received": false, "taskId": 0, "cmid": 0, "status": 0, "uncount": 1, "pushSound": 0, "flag": 1}]}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x109cfe5e0>
# receive:  {"type": 6, "messageRead": [{"userId": 102488365, "messageId": 486301632350, "readTime": 1694757493}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x109cfe5e0>
# receive:  {"type": 1, "messages": [{"from": {"uid": 102488365, "name": "孙伟", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20220907/607f1f3d68754fd010282d7e98ca8cc12901f56cccecc065b0b833dbce738f2323da15507e1ccc5d_s.jpg", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 1, "mid": 486301634484, "time": 1694757493179, "body": {"type": 12, "templateId": 1, "headTitle": "", "hyperLink": {"text": "个人简历-孙伟202308.pdf", "url": "bosszp://bosszhipin.app/openwith?type=openFile&url=https%3A%2F%2Fm.zhipin.com%2Fwflow%2Fzpgeek%2Fdownload%2Fpreview4boss%3FencryptParam%3Dbc21a2d508ef17c21HVz3dm_GVNDwIi6V_ObQOGgn-TQ&fileSize=290994&fileType=pdf&annexType=0&title=%E4%B8%AA%E4%BA%BA%E7%AE%80%E5%8E%86-%E5%AD%99%E4%BC%9F202308&subtitle=有效期至2023年12月14日&id=cd45f6c712b1e68d1XB_3dS5FVdSwg~~&ba=%7B%22p2%22%3A0%2C%22p3%22%3A0%2C%22p4%22%3A3%2C%22p%22%3A102488365%2C%22action%22%3A%22open-resume%22%7D&preCheck=1&authType=0", "hyperLinkType": 1, "extraJson": "{\"fileSizeDesc\":\"284.2KB\",\"mailTip\":\"点击预览附件简历\"}"}}, "offline": false, "received": false, "pushText": "个人简历-孙伟202308.pdf", "taskId": 0, "cmid": 0, "status": 0, "uncount": 0, "pushSound": 0, "flag": 65537}]}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x109cfe5e0>
# receive:  {"type": 4, "iqResponse": {"qid": 0, "query": "/message/suggest", "results": [{"key": "friend_source", "value": "0"}, {"key": "suggestions", "value": "[{\"label\":\"隐藏消息\",\"type\":0,\"value\":\"隐藏消息\"}]"}, {"key": "friendId", "value": "102488365"}, {"key": "msg_id", "value": "486301632350"}, {"key": "business_scene_type", "value": "1"}]}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x109c16dc0>
# receive:  {"type": 6, "messageRead": [{"userId": 102488365, "messageId": 486301633905, "readTime": 1694757493}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x109cfe5e0>
# receive:  {"type": 6, "messageRead": [{"userId": 532998144, "messageId": 485453900668, "readTime": 1694759180}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x109cfe5e0>
# receive:  {"type": 1, "messages": [{"from": {"uid": 532998144, "name": "张语莎", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20210528/e42419a1b59c30b521fdb34baaa1e6e87db518d700fae71667b3b0fce805209b_s.jpg", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 1, "mid": 486333440188, "time": 1694759196291, "body": {"type": 1, "templateId": 1, "text": "您好，请问有反馈吗", "headTitle": ""}, "offline": false, "received": false, "pushText": "张语莎:您好，请问有反馈吗", "taskId": 0, "cmid": 1152923199366043174, "status": 0, "uncount": 0, "pushSound": 0, "flag": 1}]}
# 收到文字消息:您好，请问有反馈吗
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x109c169d0>
# receive:  {"type": 6, "messageRead": [{"userId": 532998144, "messageId": 485453900668, "readTime": 1694759196}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x109c169d0>
# receive:  {"type": 4, "iqResponse": {"qid": 0, "query": "/message/suggest", "results": [{"key": "friend_source", "value": "0"}, {"key": "suggestions", "value": "[]"}, {"key": "friendId", "value": "532998144"}, {"key": "msg_id", "value": "486333440188"}, {"key": "business_scene_type", "value": "1"}]}}

# %% [markdown]
# # 上传

# %%
import requests
zijie_COOKIE='SLARDAR_WEB_ID=c4c9b5ae38477d711d12d5b2cd2fc5ad; OUTFOX_SEARCH_USER_ID_NCOO=29193230.64041566; ee-session=XN0YXJ0-751858a0-b237-5dcf-b805-9e5055769c4e-WVuZA; admin-csrf-token=dEuPxULN1JdsmSkW2Wo+RN11tAes+spKqYygc7r6MhvBJOHV8Sb7/VcFKKSAHTUOLx/rZHk4ApwPlmpnOmmjd4JWjo/YiT3LjNPEtgfZKDx7kVQ9RDH2V/bQlwTegBAuf1XBPw==; _ga=GA1.2.1570440550.1641383376; MONITOR_WEB_ID=05c64040-9a81-48f4-86ac-eb0d0a082377; people-session-7=XN0YXJ0-5s3u7q5bvdku4v03idr8ms3qauvedqhg-WVuZA; people-csrftoken=31I8vaGLV9ASzY7MlabHbM5m7HZnqKaZXUZ1niF9g2mw0LtwseEUXA9G7IlBcL1f; ttwid=1%7CIHNHFUhZfE4N8WG0gFI3-7RXOaLLa80DIWUJxJ4pPWI%7C1644477352%7Cfbe2116fe725b36a36df4eed1e07037a8417846d9f786d4dea1f1dfbb36f6970; _tea_utm_cache_1508={%22utm_source%22:%22homebutton%22%2C%22utm_medium%22:%22chrome%22}; SLARDAR_WEB_ID=zengzheng.zeal; _tea_utm_cache_1508={%22utm_source%22:%22homebutton%22%2C%22utm_medium%22:%22chrome%22}; MONITOR_DEVICE_ID=7f9263c1-4435-4136-b236-c28eaf72f4ef; MONITOR_WEB_ID=bdfc9b4869b096a0d1c6b8f0e581942f; _tea_utm_cache_4031=undefined; _tea_utm_cache_5616=undefined; lang=zh-CN; _tea_utm_cache_1943=undefined; okr-xsrf-token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHBpcmUiOiIxNjQ4NjQwMTAxIiwidGVuYW50X2lkIjoiNjY4NTMyMTU2MjcxNzMyNDgwNyIsInVzZXJfaWQiOiI2NzIzODM4MjY4MzIyMjE5NTMyIn0.AVYnj_dy7kCT8raRLjGxOB-hVGMVPTlS96pjTAoA0kU; people-fe-home-ver=Thu, 17 Mar 2022 16:08:31 GMT; atsx-csrf-token=WmQbuytQqAWbwDUSKRVo33sw2Hok0-QnMbF_PdWEuPU'
zijie_s=requests.session()
zijie_headers = {
    'Uset-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36',
#     'Cookie': zijie_COOKIE,
    'Host': 'people.bytedance.net',
    'Origin': 'https://people.bytedance.net',
    'Pragma': 'no-cache',
    'X-Requested-With': 'XMLHttpRequest',
    #'Connection': 'keep-alive',
    'Connection': 'close',
    'Cache-Control': 'no-cache',
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'zh-CN,zh;q=0.9',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'content-security-policy-report-only': '''default-src 'self' blob: data: wss: 'unsafe-inline' 'unsafe-eval' *.ibytedtos.com *.byteoversea.com *.toutiao.com *.pstatp.com *.snssdk.com *.feishu.cn *.larksuite.com *.kundou.cn *.bytedance.com *.bytedance.net *.byted.org *.alicdn.com; report-uri https://csp.snssdk.com/v19'''
}

zijie_s.headers.update(zijie_headers)



cookies =[


    ['hcloud_gar_master_sid','212e0261c1744f8901c0a9eabca6e030','.bytedance.net'],
['_ga','GA1.2.1254542092.1663211815','.bytedance.net'],
['OUTFOX_SEARCH_USER_ID_NCOO','1312703637.0917282','.bytedance.net'],
# -- 
['admin-csrf-token','+QT2T0H+brE0QfFP+lykTu81JWhb02xKsm6BkA0nHtY/CtbKpYm70XELssLuuyx12mcfuV3Qh1TU5Vkxi0HCEpErawixVuKZ2Eg/9wEjxoxy1f63n9W0SgttOM7kRpcSi7O7Nw==','.bytedance.net'],    


['SLARDAR_WEB_ID','c4c9b5ae38477d711d12d5b2cd2fc5ad','.people.bytedance.net'],
    
#---    
['gftoken','NzUxMjI0OTc2fDE2NTEyOTk2MzY4MXx8MAcHBwcHBwc','.people.bytedance.net'],
# -- 
['MONITOR_WEB_ID','bdfc9b4869b096a0d1c6b8f0e581942f','.people.bytedance.net'],

['people-csrftoken','uF1K5CYcUDNmExISw1HS8ve5D8kTty2uy2dslcKIOIIg4UtioONZoBexLH6O097y','people.bytedance.net'],
['lang','zh-CN','people.bytedance.net'],
    

['people-session-7','XN0YXJ0-cj0quso55hee5h271xhp59746r5nkqty-WVuZA','people.bytedance.net'],
    
    
['people-saas-session-v1','XN0YXJ0-3fbc5875-7382-4820-3aef-a2e0b44a8cef-WVuZA','people.bytedance.net'],
    
['people-fe-performance-ver','Thu, 21 Oct 2021 14:30:47 GMT','people.bytedance.net'],
['local_lang','zh','people.bytedance.net'],
['people-fe-home-ver','Wed, 01 Sep 2021 12:10:53 GMT','people.bytedance.net'],
#--
    ['atsx-csrf-token','kjSPsg9glUNHx9xisEyh5nb_R9HtvpW0ap4jBaYnFNg','people.bytedance.net']]

# from http.cookies import SimpleCookie
# for k,v in SimpleCookie(zijie_COOKIE).items():
#     zijie_s.cookies.set(k,v,domain='people.bytedance.net')
    
    
for k,v,d in cookies:
    zijie_s.cookies.set(k,v,domain=d)

# %%
rr=zijie_s.post('https://people.bytedance.net/atsx/api/common/csrf/token/')
zijie_s.headers['x-csrf-token']=zijie_s.cookies.get('atsx-csrf-token',domain='people.bytedance.net')

# %%
def search_job(kw):
    zijie_s.headers['Content-Type']='application/json'
    posts_params={"key_words":kw,'limit': 200,'offset': 0}
    r = zijie_s.post('https://people.bytedance.net/atsx/api/referral/job/posts/',json=posts_params)
#     print('--++ ',r.text)
    return r.json()['data']['job_post_info_list']

import os,sys,shutil,json,time,requests,random,re
# print(jobs_map)
# post_id_list=jobs_map

rr=zijie_s.post('https://people.bytedance.net/atsx/api/common/csrf/token/')
zijie_s.headers['x-csrf-token']=zijie_s.cookies.get('atsx-csrf-token',domain='people.bytedance.net')
def  time2unx(str1):
    import time, datetime
    if (not str1) or (len(str1) < 3):
        return -1
    if( len(str1)==7  ):
        str1=str1+'-01'
    timeArray = time.strptime(str1, "%Y-%m-%d")
    return int(time.mktime(timeArray)) * 1000

def check_comment(x):
    return '朋友推荐'

def upload_cv(cv_file,post_id):
    no_rm = False
    for _i in [0]:
        zijie_s.headers.update({'content-type': 'application/x-www-form-urlencoded'})
        print(post_id,cv_file)
        URL1='https://people.bytedance.net/atsx/api/common/resume/upload/tokens/'
        rsp1= zijie_s.post(URL1,json={'fake_empty': 1})
        print(rsp1,rsp1.text)
        rsp1_info = rsp1.json()
        if rsp1_info['success']:
            token = rsp1_info['data']['token']
        else:
            continue


        URL2 = 'https://people.bytedance.net/atsx/blob/{}/'.format(token)
        files={
            'content': (cv_file, open(os.path.join(RESUME_DIR, cv_file), 'rb')),
            }
        from requests_toolbelt import MultipartEncoder
        # import brotli
        m = MultipartEncoder(
            files,
            boundary='----WebKitFormBoundaryJ2aGzfsg35YqeT7X'
        )
        zijie_s.headers.update({'Content-Type': m.content_type})

        rsp2= zijie_s.post(URL2,data=m)
        print('---resp2--- ',rsp2.text)
        rsp2_info = rsp2.json()#loads(brotli.decompress(rsp2.content))
        print(rsp2_info)
        create_url = rsp2_info['data']['url']
        create_id = rsp2_info['data']['id']


        zijie_s.headers.update(
        {
        'Content-Type': 'application/json',
#         'x-csrf-token': 'IR-mWnwY5RwGtmLMMSDV21aZovUOdAEOU1wXwVD7358'
        })
        URL3 = 'https://people.bytedance.net/atsx/api/talent/resume/parse/create/'
        rsp3 = zijie_s.post(URL3,  json={'file_name': cv_file, 'resume_url':create_url})
        while True:
            rsp3_info = json.loads(rsp3.text)
            if rsp3_info["success"]:
                break
            print( rsp3_info, rsp3_info["success"], "sleep!!!")
            time.sleep(8)
        creat_token = rsp3_info['data']['token']



        URL4 = 'https://people.bytedance.net/atsx/api/talent/resume/parse/progress/?token={}'.format(creat_token)
        rsp4 = zijie_s.get(URL4)
        print('-----resp4--',rsp4.text)
        rsp4_info = json.loads(rsp4.text)
        rsp4_try = 0

        while (rsp4_info['data']['progress'] < 99):
            rsp4_try += 1
            rsp4 = zijie_s.get(URL4)
            rsp4_info = json.loads(rsp4.text)
            if rsp4_try >= 20:
                break
            time.sleep(1.0)
        talent = rsp4_info['data']['talent']
        if not talent:
            continue
        # 姓名/电话／邮箱 只要有一个没取到，就废弃该简历
        if not (talent.get("mobile", None) and talent.get("email", None) and talent.get("name", None)):
            print(  cv_file, post_id, "啥也没取到...")
            continue


        for k_k in talent :
            if type(talent[k_k])==list  :
                for i_i in range(len(talent[k_k])):
        #             print(talent[k_k][i_i])
                    if(type(talent[k_k][i_i])==dict  and type( talent[k_k][i_i].get('start_time') )==str ):
                        talent[k_k][i_i]['start_time']=time2unx(talent[k_k][i_i].get('start_time'))
                    if(type(talent[k_k][i_i])==dict  and type( talent[k_k][i_i].get('end_time') )==str ):
                        talent[k_k][i_i]['end_time']=time2unx(talent[k_k][i_i].get('end_time'))
        #                 print(time2unx(talent[k][i].get('start_time')))



        data = {
            "intention": {
                "job_category_id_list": [],
                "location_list": [],
                "recruit_type_id_list": []
            },
            "job_post": {
                "job_post_id": post_id
            },
            "referral_method": 1,
            "extra_info": {
                "relationship": 0,
                "familiarity": 0,
                "comment": check_comment(post_id)
            },
             "resume": {        
                 
                 
                 "name": talent.get("name", "未知"),
                "mobile_country_code": talent.get("mobile_code") if talent.get("mobile_code") else "CN_1",
                "mobile_number": talent.get("mobile") if talent.get("mobile") else None,
                "email": talent.get("email") if talent.get("email") else None,
                "education_list": talent["education_list"],
                "attachment_id": create_id,
                "career_list":talent.get('career_list',[]),
                "project_list":talent.get('project_list',[]),
                "internship_list":talent.get('internship_list',[]),
                "works_list":talent.get('works_list',[]),
                "award_list":talent.get('award_list',[]),
                "language_skill_list":talent.get('language_skill_list',[]),
                "sns_list":talent.get('sns_list',[]),
            }
            
            
        }
        

        URL5 = 'https://people.bytedance.net/atsx/api/referral/applications/'
        rsp5 = zijie_s.post(URL5, data=json.dumps(data))
        rsp5_info = json.loads(rsp5.text)
        print( cv_file, post_id, rsp5_info['message'])
        if rsp5_info.get("code") == -8100010:
            no_rm = True
            break
    if not no_rm:
        # os.remove(os.path.join(RESUME_DIR, cv_file))
        shutil.move(os.path.join(RESUME_DIR, cv_file),os.path.join(BACKUP_DIR, cv_file))
#     s = requests.session()
    zijie_s.keep_alive = False

def upload_cvs(eachs):
    
    for each in eachs:
        if each == '.DS_Store' or '】' not in each or  '【' not in each :
            continue
#         kw=each.split('】')[-1].split('-')[0]
#         print(each)
        kw = re.findall(r'【([a-zA-Z0-9]+)】',each)
        if not kw :
            continue
        kw=kw[-1]
        print(kw)
        if not re.match(r'(^[a-zA-Z0-9]+$)',kw):
            
            continue
        else:
            t_job=search_job(kw)
            if(not t_job):
                print("job offline ",kw,each)
                continue
            post_id=t_job[0]['id']    
            try:
#                 print(each,post_id)

                upload_cv(each,post_id)
                # print("投递成功...",unquote(cv_file))
                print("投递成功...")
                time.sleep(random.randint(1,4))
            except Exception as e:
                # print("投递成功...",unquote(cv_file))
                print("投递失败...",e)
                time.sleep(random.randint(1,2))
    print ('process_done')

if __name__  == "__main__":
    # _, file_dir, post_name = sys.argv
    # RESUME_DIR = '/Users/zengzheng.zeal/Desktop/jianli/'
    
    upload_cvs(os.listdir(RESUME_DIR))

# %% [markdown]
# # 发布

# %%
hr_blacklist={'郭梦琦':1,'谢谨同':1,'赖世海':1,'项晗':1,'张新云':1,'郭希婕':1}

posts_params={"offset":4,"limit":2
                  , "key_words":'AI'
#               ,'department_id': "6687949356450121228"
              ,"location_code_list":[
                      "CT_22", "CT_128", "CT_11", "CT_125", "CT_190",
                                     
                  "CT_154" #武汉
                                     ,"CT_119" #青岛
                                    ]} #"job_category_id_list":["6704215862603155720"],
# CT_11: 北京
# CT_125：上海

# posts_params={"offset":0,"limit":2,"job_category_id_list":["6704215882479962371"],"location_code_list":["CT_52"]}  ## 杭州运营
# posts_params={"offset":0,"limit":50,"key_words":"服务端","job_category_id_list":["6704215862603155720"],"location_code_list":["CT_52"]}  #杭州 研发 服务端 https://people.bytedance.net/hire/referral/position?limit=30&key_words=%E6%9C%8D%E5%8A%A1%E7%AB%AF&job_category_id_list=6704215862603155720&location_code_list=CT_52&current=0
# posts_params={"offset":50,"limit":20,"key_words":"销售","location_code_list":["CT_52"]}  

r = zijie_s.post('https://people.bytedance.net/atsx/api/referral/job/posts/',json=posts_params)

result_map=list(i['hr_info']['name'] for i in r.json()['data']['job_post_info_list'])
jobs=[[i['name'],i['description'],i['requirement'],i['code'],i['city_info']['name'],i['hr_info']['name']] for i in  r.json()['data']['job_post_info_list']]

codes=list(code_dict().values())
for job in jobs :
    print('hr name =>',job[5])
    job_name,job_description,job_requirement,job_code,job_city,hr_name = job
    if job_code not in codes and hr_blacklist.get(hr_name)!=1:
        publish_job_name=job_name #+'【'+job[3]+'】'
        print('--',publish_job_name)
        bot.post_job(job[3],publish_job_name, '职位描述:\n'+job_description+'\n职位要求\n'+job_requirement ,job_city)
    else:
        print('重复发布',job[0])
    time.sleep(5)
# Out:
# hr name => Coco尹佳
# -- 高级 AI 算法产品经理-剪映CapCut
# name code  AI产品经理 110110
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 1, "messages": [{"from": {"uid": 794, "name": "职位通知", "avatar": "https://img2.bosszhipin.com/boss/jobexpire.png", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 3, "mid": 533584781233, "time": 1702529803729, "body": {"type": 15, "templateId": 1, "articles": [{"title": "职位通过审核", "description": "恭喜您，您发布的职位【高级 AI 算法产品经理-剪映CapCut】已经通过审核，可以开始招募牛人了", "picUrl": "", "url": "bosszp://bosszhipin.app/openwith?type=jobview&uid=31964291&jid=326967027", "templateId": 0, "bottomText": "查看职位", "timeout": 0, "statisticParameters": "", "subTitle": ""}], "headTitle": ""}, "offline": false, "received": false, "pushText": "恭喜您，您发布的职位【高级 AI 算法产品经理-剪映CapCut】已经通过审核，可以开始招募牛人了", "taskId": 0, "cmid": 0, "status": 0, "uncount": 0, "pushSound": 0, "flag": 1}]}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 1, "messages": [{"from": {"uid": 798, "name": "活动通知", "avatar": "https://img2.bosszhipin.com/app/android/activity-19adbc8b410ae3b00ed3f39b6dddfaa3.png", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 3, "mid": 533584783344, "time": 1702529804100, "body": {"type": 15, "templateId": 1, "articles": [{"title": "提升“高级 AI 算法产品经理-剪映CapCut”职位招聘效率", "description": "推荐您使用\"急聘直通卡\"，可增强曝光3000+次，保证至少150人查看", "picUrl": "https://img.bosszhipin.com/beijin/upload/tmp/20210712/c9046beeb01fb1b7fa924fc1e04cd7e6227e517b66ca8ea12d42a67c1c41827a.png", "url": "https://m.zhipin.com/mpa/html/props/product/99?encryptJobId=7d0fc6d85c15f9141HZ80tu6EFBX&encryptAppId=7d133318365793281g~~&sid=f1-jipin-try&source=secretary&jobSource=3&buyScene=1", "templateId": 0, "bottomText": "", "timeout": 0, "statisticParameters": "{\"action\":\"detail-notify-msg\",\"p\":\"533584783344\",\"p2\":1,\"p4\":326967027,\"p5\":\"提升“高级AI算法产品经理-剪映CapCut”职位招聘效率\",\"p6\":9,\"p8\":\"quick-top-card\",\"p9\":3,\"p12\":1}", "subTitle": ""}, {"title": "立即体验", "description": "立即体验", "picUrl": "", "url": "bosszp://bosszhipin.pc/openPage?type=openDialog&dialogName=business&itemType=9&encryptItemType=5420b304e3e27fdf3g~~&buyOrConsume=buy&source=secretary&encryptJobId=7d0fc6d85c15f9141HZ80tu6EFBX&buyScene=1", "templateId": 0, "bottomText": "", "timeout": 0, "statisticParameters": "{\"action\":\"detail-notify-msg\",\"p\":\"533584783344\",\"p2\":1,\"p4\":326967027,\"p5\":\"提升“高级AI算法产品经理-剪映CapCut”职位招聘效率\",\"p6\":9,\"p8\":\"quick-top-card\",\"p9\":3,\"p12\":1}", "subTitle": ""}], "headTitle": ""}, "offline": false, "received": false, "pushText": "推荐您使用\"急聘直通卡\"，可增强曝光3000+次，保证至少150人查看", "taskId": 0, "cmid": 0, "status": 0, "uncount": 0, "pushSound": 0, "flag": 1}]}
# name code  高级 AI 算法产品经理-剪映CapCut A104376 {'code': 0, 'message': 'Success', 'zpData': {'blockTitle': '职位发布成功', 'publishScene': 0, 'overseasMaterialsHunterDialog': None, 'itemInfo': {'itemType': 0, 'flag': 1, 'encryptUserItemId': None, 'buttonPcUrl': None}, 'resmsg': '职位已发布成功', 'blockVipRenewTip': None, 'rescode': 1, 'jobId': '7d0fc6d85c15f9141HZ80tu6EFBX', 'buyQuickTop': 1, 'disabledPromoteDialog': None, 'qualityCertHighlightDialog': None, 'auditStatus': 3, 'jobAuditingInfo': None}}
# hr name => Coco尹佳
# -- 高级 AI 算法产品经理-剪映CapCut
# name code  AI产品经理 110110
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 1, "messages": [{"from": {"uid": 794, "name": "职位通知", "avatar": "https://img2.bosszhipin.com/boss/jobexpire.png", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 3, "mid": 533584820903, "time": 1702529810314, "body": {"type": 15, "templateId": 1, "articles": [{"title": "职位通过审核", "description": "恭喜您，您发布的职位【高级 AI 算法产品经理-剪映CapCut】已经通过审核，可以开始招募牛人了", "picUrl": "", "url": "bosszp://bosszhipin.app/openwith?type=jobview&uid=31964291&jid=326967037", "templateId": 0, "bottomText": "查看职位", "timeout": 0, "statisticParameters": "", "subTitle": ""}], "headTitle": ""}, "offline": false, "received": false, "pushText": "恭喜您，您发布的职位【高级 AI 算法产品经理-剪映CapCut】已经通过审核，可以开始招募牛人了", "taskId": 0, "cmid": 0, "status": 0, "uncount": 0, "pushSound": 0, "flag": 1}]}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 1, "messages": [{"from": {"uid": 798, "name": "活动通知", "avatar": "https://img2.bosszhipin.com/app/android/activity-19adbc8b410ae3b00ed3f39b6dddfaa3.png", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 3, "mid": 533584823133, "time": 1702529810722, "body": {"type": 15, "templateId": 1, "articles": [{"title": "提升“高级 AI 算法产品经理-剪映CapCut”职位招聘效率", "description": "推荐您使用\"急聘直通卡\"，可增强曝光3000+次，保证至少150人查看", "picUrl": "https://img.bosszhipin.com/beijin/upload/tmp/20210712/c9046beeb01fb1b7fa924fc1e04cd7e6227e517b66ca8ea12d42a67c1c41827a.png", "url": "https://m.zhipin.com/mpa/html/props/product/99?encryptJobId=cac21fef47621f7e1HZ80tu6EFFX&encryptAppId=7d133318365793281g~~&sid=f1-jipin-try&source=secretary&jobSource=3&buyScene=1", "templateId": 0, "bottomText": "", "timeout": 0, "statisticParameters": "{\"action\":\"detail-notify-msg\",\"p\":\"533584823133\",\"p2\":1,\"p4\":326967037,\"p5\":\"提升“高级AI算法产品经理-剪映CapCut”职位招聘效率\",\"p6\":9,\"p8\":\"quick-top-card\",\"p9\":3,\"p12\":1}", "subTitle": ""}, {"title": "立即体验", "description": "立即体验", "picUrl": "", "url": "bosszp://bosszhipin.pc/openPage?type=openDialog&dialogName=business&itemType=9&encryptItemType=5420b304e3e27fdf3g~~&buyOrConsume=buy&source=secretary&encryptJobId=cac21fef47621f7e1HZ80tu6EFFX&buyScene=1", "templateId": 0, "bottomText": "", "timeout": 0, "statisticParameters": "{\"action\":\"detail-notify-msg\",\"p\":\"533584823133\",\"p2\":1,\"p4\":326967037,\"p5\":\"提升“高级AI算法产品经理-剪映CapCut”职位招聘效率\",\"p6\":9,\"p8\":\"quick-top-card\",\"p9\":3,\"p12\":1}", "subTitle": ""}], "headTitle": ""}, "offline": false, "received": false, "pushText": "推荐您使用\"急聘直通卡\"，可增强曝光3000+次，保证至少150人查看", "taskId": 0, "cmid": 0, "status": 0, "uncount": 0, "pushSound": 0, "flag": 1}]}
# name code  高级 AI 算法产品经理-剪映CapCut A62049 {'code': 0, 'message': 'Success', 'zpData': {'blockTitle': '职位发布成功', 'publishScene': 0, 'overseasMaterialsHunterDialog': None, 'itemInfo': {'itemType': 0, 'flag': 1, 'encryptUserItemId': None, 'buttonPcUrl': None}, 'resmsg': '职位已发布成功', 'blockVipRenewTip': None, 'rescode': 1, 'jobId': 'cac21fef47621f7e1HZ80tu6EFFX', 'buyQuickTop': 1, 'disabledPromoteDialog': None, 'qualityCertHighlightDialog': None, 'auditStatus': 3, 'jobAuditingInfo': None}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d5cecc80>
# receive:  {"type": 1, "messages": [{"from": {"uid": 79282350, "name": "操刚", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20230529/607f1f3d68754fd0dfe53fbb105de37bd2fed580803d64e54aad486aa5e8a5ec104da20e3d601516_s.jpg", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 3, "mid": 533588159876, "time": 1702530320037, "body": {"type": 4, "templateId": 1, "action": {"aid": 51, "extend": "{\"jobId\":271180122,\"expectId\":395999350,\"syncInfo\":1}"}, "headTitle": ""}, "offline": false, "received": false, "taskId": 0, "cmid": 0, "status": 0, "uncount": 1, "pushSound": 0, "flag": 1}]}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d5cecc80>
# receive:  {"type": 4, "iqResponse": {"qid": 0, "query": "/message/suggest", "results": [{"key": "suggestions", "value": "[]"}, {"key": "friendId", "value": "79282350"}, {"key": "msg_id", "value": "0"}, {"key": "business_scene_type", "value": "7"}]}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d5cecc80>
# receive:  {"type": 1, "messages": [{"from": {"uid": 79282350, "name": "操刚", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20230529/607f1f3d68754fd0dfe53fbb105de37bd2fed580803d64e54aad486aa5e8a5ec104da20e3d601516_s.jpg", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 3, "mid": 533588160366, "time": 1702530320037, "body": {"type": 9, "templateId": 3, "headTitle": "点击查看牛人简历", "resume": {"user": {"uid": 79282350, "name": "操刚", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20230529/607f1f3d68754fd0dfe53fbb105de37bd2fed580803d64e54aad486aa5e8a5ec104da20e3d601516_s.jpg", "company": "", "headImg": 0, "certification": 0}, "description": "", "city": "深圳", "position": "期望：测试工程师", "expectId": 395999350, "lid": "", "gender": 1, "salary": "18-20K", "workYear": "4年", "content1": "求职期望  测试工程师", "content2": "毕业于 江汉大学 | 汽车服务工程", "education": "本科", "age": "28", "experiences": [{"organization": "纬创软件", "occupation": "自动化测试", "startDate": "2021.04", "endDate": "至今", "type": 1}, {"organization": "江汉大学", "occupation": "汽车服务工程", "startDate": "2014", "endDate": "2018", "type": 2}], "positionCategory": "移动端leader-飞书多维表格", "jobSalary": "25-50K", "bottomText": "12月14日 沟通的职位-移动端leader-飞书多维表格", "applyStatus": "在职-考虑机会", "jobId": 271180122}}, "offline": false, "received": false, "taskId": 0, "cmid": 0, "status": 0, "uncount": 1, "pushSound": 0, "flag": 1}]}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d5cecc80>
# receive:  {"type": 1, "messages": [{"from": {"uid": 79282350, "name": "操刚", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20230529/607f1f3d68754fd0dfe53fbb105de37bd2fed580803d64e54aad486aa5e8a5ec104da20e3d601516_s.jpg", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 3, "mid": 533588160485, "time": 1702530320070, "body": {"type": 1, "templateId": 1, "text": "Boss，可以和您聊聊这个岗位需求吗？", "headTitle": ""}, "offline": false, "received": false, "pushText": "操刚:Boss，可以和您聊聊这个岗位需求吗？", "taskId": 0, "cmid": 0, "status": 0, "uncount": 0, "pushSound": 0, "flag": 1}]}
# (0, 13)
# exchange_request  <Response [200]>
# change_note {'uid': 79282350, 'encryptUid': '0b8c9c38405bb4610H1409--FVI~', 'lastTime': '13:05', 'encryptExpectId': '1674efd5e39552f51H1_0tS0E1dQ', 'addTime': '2023-12-14', 'year': '4年', 'lowSalary': 25, 'highSalary': 50, 'salaryDesc': '25-50K', 'geoId': 'B0I0571UJS', 'showCandidate': 0, 'firstTalk': False, 'major': '汽车服务工程', 'school': '江汉大学', 'price': '18-20K', 'bothTalked': False, 'block': False, 'applyStatusDes': '现任', 'applyStatusDes2': '曾任', 'ageDesc': '28岁', 'toPosition': '移动端leader-飞书多维表格', 'weixinVisible': 0, 'sourceTitle': None, 'labels': [], 'newGeek': 1, 'jobId': 271180122, 'weixin': None, 'toPositionId': 'f5787b4ccd5543fb1XN72tW9EVBS', 'phone': None, 'regionCode': None, 'sourceType': 2, 'sourceExtend': None, 'isTop': 0, 'edu': '本科', 'name': '操刚', 'nameRareChars': None, 'largeAvatar': 'https://img.bosszhipin.com/beijin/upload/avatar/20230529/607f1f3d68754fd0dfe53fbb105de37bd2fed580803d64e54aad486aa5e8a5ec104da20e3d601516.jpg', 'position': '测试工程师', 'positionName': '移动端leader-飞书多维表格', 'encProjectId': None, 'applyStatus': 2, 'lastCompany2': '微创软件', 'note': '', 'gender': 1, 'city': '深圳', 'resumeVisible': 0, 'mobileVisible': 0, 'cooperate': 2, 'expectId': 395999350, 'expectType': 0, 'outCount': 0, 'inCount': 1, 'belongGroup': None, 'lastPosition': '自动化测试', 'avatar': 'https://img.bosszhipin.com/beijin/upload/avatar/20230529/607f1f3d68754fd0dfe53fbb105de37bd2fed580803d64e54aad486aa5e8a5ec104da20e3d601516_s.jpg', 'lastCompany': '纬创软件', 'positionStatus': '在职-考虑机会', 'initTime': '13:05', 'interview': 0, 'lastPosition2': '测试工程师', 'relationType': 5, 'securityId': 'Diw0FAjphdCyB-V18yLtsCdycHMhUoJNBVT8Unm3_Vug7ShFVW0HuQeyDbo6BpoaiPN3kDYmDuFum4sEWZXxVo4Ez0yyCQXdlqYgXF6RDJJYfaTdbV5SNE6UehrrdNjH73evvevxYZUCmI-FTx9C0G6jsT456UfYdrDpklLLp61AzahOzvN7ZilKJwnNB2ZDMczp7YXi4a78le9Y2RD0Wr9GmhxRkX9ZJwK62CNGqdiuTKyKZbGBl6VL03asrkxdXvRj85o5_ERcLS9xGj04MpNxCTtdEAyx9MvnWt-Fg0Ux6aCjj6Hqm-_CBU9fQtSEMEfzto85nZaD-sqL3Cm3Vk8wJ7heFlPfMf2yHWjHQ18QpwzIpMGUJ3kvNK32GVCqjZ5VuGlFPAcTt6vng6quCsgvB271vh_62pBScHDhnlXyidwhFxHrsoeNQTdnuOEEpCnIirFjFFYrxUIG3_mUTUPtqnbsaWWvBU24yID1UzACdI_vF0bFJeyNBGHHR_Ld25HyvgAl4bZpetUHpUpZsgK9Zw2EyrgTaBprFAmuH-u-vMNwE9GDdgyKlw~~', 'filterReasonList': None, 'everWorkPositionNameList': None, 'workExpList': [{'timeDesc': '2021.04-至今', 'company': '纬创软件', 'positionName': '自动化测试'}, {'timeDesc': '2019.11-2021.04', 'company': '微创软件', 'positionName': '测试工程师'}], 'eduExpList': [{'timeDesc': '2014-2018', 'school': '江汉大学', 'major': '汽车服务工程', 'degree': '本科', 'degreeCode': 203}], 'activeTimeDesc': '刚刚活跃', 'completeType': 0, 'resumeVideoInfo': None, 'multiGeekVideoResume4BossVO': None, 'highLightGeekResumeWords': ['性能数据', '埋点', '交叉测试', '启动任务', 'SDK'], 'enablePmq': False, 'geekFreeStatus': 0, 'hasJobCompetitive': 0, 'myGeekState': 0, 'hasItemBackGroundSurvey': 0, 'userFriendLabels': [], 'itemBannerVO': {'display': 0, 'buttonText': None, 'jumpUrl': None, 'text': None, 'subText': None, 'icon': None, 'type': 0}, 'showEyeBrow': False, 'geekInfoNull': False, 'recommendReason': None, 'potentialJobInterest': None, 'systemJob': False, 'closeInterview': False, 'filtered': False, 'isSystemJob': False, 'isCloseInterview': False, 'isFiltered': False} 已聊 {"code":0,"message":"Success","zpData":{"result":true}}
# 收到文字消息:Boss，可以和您聊聊这个岗位需求吗？
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d5cecc80>
# receive:  {"type": 6, "messageRead": [{"userId": 79282350, "messageId": 533588160010, "readTime": 1702530319842}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d5cecc80>
# receive:  {"type": 6, "messageRead": [{"userId": 79282350, "messageId": 533588160264, "readTime": 1702530319938}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d5cecc80>
# receive:  {"type": 5, "messageSync": [{"clientMid": 1702530320764, "serverMid": 533588167060}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 4, "iqResponse": {"qid": 0, "query": "/message/suggest", "results": [{"key": "friend_source", "value": "0"}, {"key": "suggestions", "value": "[{\"label\":\"隐藏消息\",\"type\":0,\"value\":\"隐藏消息\"}]"}, {"key": "friendId", "value": "79282350"}, {"key": "msg_id", "value": "533588167060"}, {"key": "business_scene_type", "value": "7"}]}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 4, "iqResponse": {"qid": 0, "query": "/message/suggest", "results": [{"key": "friend_source", "value": "0"}, {"key": "suggestions", "value": "[{\"label\":\"隐藏消息\",\"type\":0,\"value\":\"隐藏消息\"}]"}, {"key": "friendId", "value": "79282350"}, {"key": "msg_id", "value": "533588167060"}, {"key": "business_scene_type", "value": "1"}]}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 4, "iqResponse": {"qid": 0, "query": "/message/suggest", "results": [{"key": "friend_source", "value": "0"}, {"key": "suggestions", "value": "[]"}, {"key": "friendId", "value": "79282350"}, {"key": "msg_id", "value": "533588167060"}, {"key": "business_scene_type", "value": "1"}]}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 6, "messageRead": [{"userId": 79282350, "messageId": 533588167060, "readTime": 1702530325266}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 1, "messages": [{"from": {"uid": 79282350, "name": "操刚", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20230529/607f1f3d68754fd0dfe53fbb105de37bd2fed580803d64e54aad486aa5e8a5ec104da20e3d601516_s.jpg", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 1, "mid": 533588383343, "time": 1702530351163, "body": {"type": 7, "templateId": 1, "dialog": {"text": "对方想发送附件简历给您，您是否同意", "buttons": [{"text": "同意", "url": "bosszp://bosszhipin.app/openwith?type=sendaction&uid=79282350&aid=41&extends=%7B%22resumeName%22%3A%22%E6%AD%A6%E6%B1%89%E8%87%AA%E5%8A%A8%E5%8C%96%E6%B5%8B%E8%AF%95.pdf%22%2C%22resumeId%22%3A257088823%2C%22resumeRevocable%22%3A1%2C%22annexType%22%3A2%7D", "templateId": 0}, {"text": "拒绝", "url": "bosszp://bosszhipin.app/openwith?type=sendaction&uid=79282350&aid=42&extends=%7B%22resumeName%22%3A%22%E6%AD%A6%E6%B1%89%E8%87%AA%E5%8A%A8%E5%8C%96%E6%B5%8B%E8%AF%95.pdf%22%2C%22resumeId%22%3A257088823%2C%22resumeRevocable%22%3A1%2C%22annexType%22%3A2%7D", "templateId": 1}], "operated": false, "clickMore": false, "type": 2, "backgroundUrl": "", "timeout": 0, "statisticParameters": "", "title": "", "url": ""}, "headTitle": ""}, "offline": false, "received": false, "pushText": "操刚:对方想发送附件简历给您，您是否同意", "taskId": 0, "cmid": 0, "status": 0, "uncount": 0, "pushSound": 0, "flag": 65537}]}
# exchange_accept:get info  {'uid': 79282350, 'encryptUid': '0b8c9c38405bb4610H1409--FVI~', 'lastTime': '13:05', 'encryptExpectId': '1674efd5e39552f51H1_0tS0E1dQ', 'addTime': '2023-12-14', 'year': '4年', 'lowSalary': 25, 'highSalary': 50, 'salaryDesc': '25-50K', 'geoId': 'B0I0571UJS', 'showCandidate': 0, 'firstTalk': False, 'major': '汽车服务工程', 'school': '江汉大学', 'price': '18-20K', 'bothTalked': True, 'block': False, 'applyStatusDes': '现任', 'applyStatusDes2': '曾任', 'ageDesc': '28岁', 'toPosition': '移动端leader-飞书多维表格', 'weixinVisible': 0, 'sourceTitle': None, 'labels': [], 'newGeek': 1, 'jobId': 271180122, 'weixin': None, 'toPositionId': 'f5787b4ccd5543fb1XN72tW9EVBS', 'phone': None, 'regionCode': None, 'sourceType': 2, 'sourceExtend': None, 'isTop': 0, 'edu': '本科', 'name': '操刚', 'nameRareChars': None, 'largeAvatar': 'https://img.bosszhipin.com/beijin/upload/avatar/20230529/607f1f3d68754fd0dfe53fbb105de37bd2fed580803d64e54aad486aa5e8a5ec104da20e3d601516.jpg', 'position': '测试工程师', 'positionName': '移动端leader-飞书多维表格', 'encProjectId': None, 'applyStatus': 2, 'lastCompany2': '微创软件', 'note': '已聊', 'gender': 1, 'city': '深圳', 'resumeVisible': 0, 'mobileVisible': 0, 'cooperate': 2, 'expectId': 395999350, 'expectType': 0, 'outCount': 1, 'inCount': 1, 'belongGroup': None, 'lastPosition': '自动化测试', 'avatar': 'https://img.bosszhipin.com/beijin/upload/avatar/20230529/607f1f3d68754fd0dfe53fbb105de37bd2fed580803d64e54aad486aa5e8a5ec104da20e3d601516_s.jpg', 'lastCompany': '纬创软件', 'positionStatus': '在职-考虑机会', 'initTime': '13:05', 'interview': 0, 'lastPosition2': '测试工程师', 'relationType': 6, 'securityId': '03OfSTKtu7cIp-q1xcQaBS5sRFRF7SbnObRmBz4aQo-b6o6CZ3nKi137N7bR1KNNuli0SPa9f6r3_o-v205BiZ_mtpkSaRvEbEJo8e0YUxFr0z2WJoXz82yZAlLwqKI0K3vlZBk1M03D3e-5Saw4y5Tj8OOAVu1VT3IoQ6cMOyS0YWtlzvAakepr2Oer4ZRwCMkDyovWxCq7K-P39smWluqa4GjstMvN69uOh_S4RCdJo_olOK7rRo7y_FEOD-4ZbpqTEGIPOVZOEDy-eozIoahyxas60Sow1863LhzZecvBbXxnxSrR-sLzfXub6AXHP2gL9JbvipqnT3A7dx5JSqofQ3iumSF2itVSQcXnzOEqbH0RqShd4ndXW6opxWLTpPIi38yoFKadzyvdDBqZ2ydhqVToMM8CDy5dZ2YeEmXFfu1cOKLX_2HyXKJzX60qdL1q8ODUPHinY-8ECcL1A80HBnTVOJJD1OnQtLMaITxyTky7cAvoEH4VW_b5h5tDQAN_TwbHlv8UOF-_CvcQLyI_O4hVSbu2Ik4lQgRxoO8U0SJhUjjAcR9yDQ~~', 'filterReasonList': None, 'everWorkPositionNameList': None, 'workExpList': [{'timeDesc': '2021.04-至今', 'company': '纬创软件', 'positionName': '自动化测试'}, {'timeDesc': '2019.11-2021.04', 'company': '微创软件', 'positionName': '测试工程师'}], 'eduExpList': [{'timeDesc': '2014-2018', 'school': '江汉大学', 'major': '汽车服务工程', 'degree': '本科', 'degreeCode': 203}], 'activeTimeDesc': '刚刚活跃', 'completeType': 0, 'resumeVideoInfo': None, 'multiGeekVideoResume4BossVO': None, 'highLightGeekResumeWords': ['性能数据', '埋点', '交叉测试', '启动任务', 'SDK'], 'enablePmq': False, 'geekFreeStatus': 0, 'hasJobCompetitive': 0, 'myGeekState': 0, 'hasItemBackGroundSurvey': 0, 'userFriendLabels': [], 'itemBannerVO': {'display': 0, 'buttonText': None, 'jumpUrl': None, 'text': None, 'subText': None, 'icon': None, 'type': 0}, 'showEyeBrow': False, 'geekInfoNull': False, 'recommendReason': None, 'potentialJobInterest': None, 'systemJob': False, 'closeInterview': False, 'filtered': False, 'isSystemJob': False, 'isCloseInterview': False, 'isFiltered': False}
# exchange_accept  <Response [200]>
# -------=-=-=- f5787b4ccd5543fb1XN72tW9EVBS 移动端leader-飞书多维表格
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 1, "messages": [{"from": {"uid": 79282350, "name": "操刚", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20230529/607f1f3d68754fd0dfe53fbb105de37bd2fed580803d64e54aad486aa5e8a5ec104da20e3d601516_s.jpg", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 4, "mid": 533588383640, "time": 1702530351195, "body": {"type": 12, "templateId": 1, "headTitle": "", "hyperLink": {"text": "您可以在线预览牛人简历，设置邮箱后投递的简历会同时发送到您的邮箱。", "url": "bosszp://bosszhipin.app/openwith?type=updateResumeEmail", "hyperLinkType": 6, "extraJson": "{\"highlightLength\":4,\"highlightStart\":12}"}}, "offline": false, "received": false, "pushText": "您可以在线预览牛人简历，设置邮箱后投递的简历会同时发送到您的邮箱。", "taskId": 0, "cmid": 0, "status": 0, "uncount": 1, "pushSound": 0, "flag": 1}]}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 4, "iqResponse": {"qid": 0, "query": "/message/suggest", "results": [{"key": "friend_source", "value": "0"}, {"key": "suggestions", "value": "[{\"label\":\"隐藏消息\",\"type\":0,\"value\":\"隐藏消息\"}]"}, {"key": "friendId", "value": "79282350"}, {"key": "msg_id", "value": "533588383282"}, {"key": "business_scene_type", "value": "1"}]}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 6, "messageRead": [{"userId": 79282350, "messageId": 533588383482, "readTime": 1702530350976}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 1, "messages": [{"from": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "", "headImg": 15, "certification": 0}, "to": {"uid": 79282350, "name": "操刚", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20230529/607f1f3d68754fd0dfe53fbb105de37bd2fed580803d64e54aad486aa5e8a5ec104da20e3d601516_s.jpg", "company": "", "headImg": 0, "certification": 0}, "type": 1, "mid": 533588386568, "time": 1702530351571, "body": {"type": 4, "templateId": 1, "action": {"aid": 41, "extend": "{\"resumeName\":\"武汉自动化测试.pdf\",\"resumeId\":257088823,\"annexType\":2,\"resumeRevocable\":1}"}, "headTitle": ""}, "offline": false, "received": false, "taskId": 0, "cmid": 0, "status": 0, "uncount": 1, "pushSound": 0, "flag": 1}]}
# err geek_info 31964291 {'code': 0, 'message': 'Success', 'zpData': {'msg': '已在其他设备删除该好友，该会话已经关闭。', 'status': -1}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 1, "messages": [{"from": {"uid": 79282350, "name": "操刚", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20230529/607f1f3d68754fd0dfe53fbb105de37bd2fed580803d64e54aad486aa5e8a5ec104da20e3d601516_s.jpg", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 3, "mid": 533588386565, "time": 1702530351577, "body": {"type": 4, "templateId": 1, "action": {"aid": 97, "extend": "{\"mid\":533588383343}"}, "headTitle": ""}, "offline": false, "received": false, "taskId": 0, "cmid": 0, "status": 0, "uncount": 1, "pushSound": 0, "flag": 1}]}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 1, "messages": [{"from": {"uid": 79282350, "name": "操刚", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20230529/607f1f3d68754fd0dfe53fbb105de37bd2fed580803d64e54aad486aa5e8a5ec104da20e3d601516_s.jpg", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 1, "mid": 533588387008, "time": 1702530351632, "body": {"type": 12, "templateId": 1, "headTitle": "", "hyperLink": {"text": "武汉自动化测试.pdf", "url": "bosszp://bosszhipin.app/openwith?type=openFile&url=https%3A%2F%2Fm.zhipin.com%2Fwflow%2Fzpgeek%2Fdownload%2Fpreview4boss%3FencryptParam%3D3c27801ebddfb3261HVz3dm_GVNDwIq3V_-dQuKjnOTQ&fileSize=113758&fileType=pdf&annexType=2&title=%E6%AD%A6%E6%B1%89%E8%87%AA%E5%8A%A8%E5%8C%96%E6%B5%8B%E8%AF%95&subtitle=有效期至2024年03月13日&id=e37a580c5fab53aa1XJy3di_F1RRwQ~~&ba=%7B%22p2%22%3A0%2C%22p3%22%3A0%2C%22p4%22%3A3%2C%22p%22%3A79282350%2C%22action%22%3A%22open-resume%22%7D&preCheck=1&authType=0", "hyperLinkType": 1, "extraJson": "{\"fileSizeDesc\":\"111.1KB\",\"mailTip\":\"点击预览附件简历\"}"}}, "offline": false, "received": false, "pushText": "武汉自动化测试.pdf", "taskId": 0, "cmid": 0, "status": 0, "uncount": 0, "pushSound": 0, "flag": 65537}]}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 6, "messageRead": [{"userId": 79282350, "messageId": 533588386897, "readTime": 1702530354132}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 1, "messages": [{"from": {"uid": 50244003, "name": "谢少平", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20230830/607f1f3d68754fd06f02b8d1c2665afa357ca9c0bcd523c35233a8901214fc6b2dbbc3bc663fd131_s.jpg.webp", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 3, "mid": 533595626546, "time": 1702531170263, "body": {"type": 4, "templateId": 1, "action": {"aid": 51, "extend": "{\"jobId\":326966816,\"expectId\":771087048,\"syncInfo\":1}"}, "headTitle": ""}, "offline": false, "received": false, "taskId": 0, "cmid": 0, "status": 0, "uncount": 1, "pushSound": 0, "flag": 1}]}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 4, "iqResponse": {"qid": 0, "query": "/message/suggest", "results": [{"key": "suggestions", "value": "[]"}, {"key": "friendId", "value": "50244003"}, {"key": "msg_id", "value": "0"}, {"key": "business_scene_type", "value": "7"}]}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 1, "messages": [{"from": {"uid": 50244003, "name": "谢少平", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20230830/607f1f3d68754fd06f02b8d1c2665afa357ca9c0bcd523c35233a8901214fc6b2dbbc3bc663fd131_s.jpg.webp", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 3, "mid": 533595626793, "time": 1702531170264, "body": {"type": 9, "templateId": 3, "headTitle": "点击查看牛人简历", "resume": {"user": {"uid": 50244003, "name": "谢少平", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20230830/607f1f3d68754fd06f02b8d1c2665afa357ca9c0bcd523c35233a8901214fc6b2dbbc3bc663fd131_s.jpg.webp", "company": "", "headImg": 0, "certification": 0}, "description": "", "city": "北京", "position": "期望：用户运营", "expectId": 771087048, "lid": "", "gender": 1, "salary": "25-40K", "workYear": "10年以上", "content1": "求职期望  用户运营", "content2": "毕业于 兰州大学 | 传播学", "education": "硕士", "age": "38", "experiences": [{"organization": "Eolink｜广州银云科技", "occupation": "用户运营", "startDate": "2021.12", "endDate": "至今", "type": 1}, {"organization": "兰州大学", "occupation": "传播学", "startDate": "2014", "endDate": "2017", "type": 2}], "positionCategory": "AI高级产品经理-飞书", "jobSalary": "25-50K", "bottomText": "12月14日 沟通的职位-AI高级产品经理-飞书", "applyStatus": "在职-考虑机会", "jobId": 326966816}}, "offline": false, "received": false, "taskId": 0, "cmid": 0, "status": 0, "uncount": 1, "pushSound": 0, "flag": 1}]}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 1, "messages": [{"from": {"uid": 50244003, "name": "谢少平", "avatar": "https://img.bosszhipin.com/beijin/upload/avatar/20230830/607f1f3d68754fd06f02b8d1c2665afa357ca9c0bcd523c35233a8901214fc6b2dbbc3bc663fd131_s.jpg.webp", "company": "", "headImg": 0, "certification": 0}, "to": {"uid": 31964291, "name": "曾政", "avatar": "https://img.bosszhipin.com/boss/avatar/avatar_15.png", "company": "今日头条", "headImg": 15, "certification": 3}, "type": 3, "mid": 533595626868, "time": 1702531170294, "body": {"type": 1, "templateId": 1, "text": "您好，我仔细阅读了您发布的这个职位，和我自己比较匹配，希望能与您进一步沟通一下，期待您的回复", "headTitle": ""}, "offline": false, "received": false, "pushText": "谢少平:您好，我仔细阅读了您发布的这个职位，和我自己比较匹配，希望能与您进一步沟通一下，期待您的回复", "taskId": 0, "cmid": 0, "status": 0, "uncount": 0, "pushSound": 0, "flag": 1}]}
# (0, 14)
# exchange_request  <Response [200]>
# change_note {'uid': 50244003, 'encryptUid': 'b595ad7dae4846bd0nR439m9EFE~', 'lastTime': '13:19', 'encryptExpectId': '89e3cfd957f64abc0HN729W6EFZY', 'addTime': '2023-12-14', 'year': '10年以上', 'lowSalary': 25, 'highSalary': 50, 'salaryDesc': '25-50K', 'geoId': 'B0FFHF59SJ', 'showCandidate': 0, 'firstTalk': False, 'major': '传播学', 'school': '兰州大学', 'price': '25-40K', 'bothTalked': False, 'block': False, 'applyStatusDes': '现任', 'applyStatusDes2': '曾任', 'ageDesc': '38岁', 'toPosition': 'AI高级产品经理-飞书', 'weixinVisible': 0, 'sourceTitle': None, 'labels': [], 'newGeek': 1, 'jobId': 326966816, 'weixin': None, 'toPositionId': '62121e14d8204a7f1HZ80tu7GFNW', 'phone': None, 'regionCode': None, 'sourceType': 2, 'sourceExtend': None, 'isTop': 0, 'edu': '硕士', 'name': '谢少平', 'nameRareChars': None, 'largeAvatar': 'https://img.bosszhipin.com/beijin/upload/avatar/20230830/607f1f3d68754fd06f02b8d1c2665afa357ca9c0bcd523c35233a8901214fc6b2dbbc3bc663fd131.jpg.webp', 'position': '用户运营', 'positionName': 'AI高级产品经理-飞书', 'encProjectId': None, 'applyStatus': 2, 'lastCompany2': '阳光保险集团', 'note': '', 'gender': 1, 'city': '北京', 'resumeVisible': 0, 'mobileVisible': 0, 'cooperate': 2, 'expectId': 771087048, 'expectType': 0, 'outCount': 0, 'inCount': 1, 'belongGroup': None, 'lastPosition': '用户运营', 'avatar': 'https://img.bosszhipin.com/beijin/upload/avatar/20230830/607f1f3d68754fd06f02b8d1c2665afa357ca9c0bcd523c35233a8901214fc6b2dbbc3bc663fd131_s.jpg.webp', 'lastCompany': 'Eolink｜广州银云科技', 'positionStatus': '在职-考虑机会', 'initTime': '13:19', 'interview': 0, 'lastPosition2': '运营经理/主管', 'relationType': 5, 'securityId': 'p3RFuxJkqiuqP-j11Q7ASU4R-fPrvr2pU8UrkQ8Gw22vc4oied7aQb_KJSGb_114h_SdKtDnF9-xQ3EC650NcCq6t9WrkgHbqnHJEYfa_HwEAl5oyRagLjYUZgzkgTAwmzH1e7VBlB0bqbg7QYketIFuE_7xEfUyhcY9Jk6sQkiwdBZ5aSn_JBuoiT3e-Z6otTAe5PCYtoYQL6uTsFXSQ2JJ42ePx7QE59lhUF2714A3NoKbdkxXIJi9bAt1aJFUlD8fNFeeMEDRLMY_7uphAM1kemUg251EHlcuwN30BIaoYAb6gWV9dr0_rwkijc9VpE9XD1b0u89d3W3zp9BrUBp2q_Ys1544WFWDdg2sdLD5h5t3Pw_lnBTVGisrXzKEOFlqcUL9nvKDPu1acn52X7i-dpCKO1yLWn3jb2tQbjnYWoQbUer_RmunCrV1Qnak7Bq6ptc1NJdYV7pNt-l4o1JJUWtER0o4F3UPYgrI5zBdTIkowuD6ESjUgwevjkUd6MVgPJZztg-Mu9Al7Uluih-rXJqjodZdm07GjsZfNTLj_lnGhyZ-W5i2Tg~~', 'filterReasonList': None, 'everWorkPositionNameList': None, 'workExpList': [{'timeDesc': '2021.12-至今', 'company': 'Eolink｜广州银云科技', 'positionName': '用户运营'}, {'timeDesc': '2021.02-2021.12', 'company': '阳光保险集团', 'positionName': '运营经理/主管'}], 'eduExpList': [{'timeDesc': '2014-2017', 'school': '兰州大学', 'major': '传播学', 'degree': '硕士', 'degreeCode': 204}, {'timeDesc': '2005-2009', 'school': '武汉理工大学', 'major': '通信工程', 'degree': '本科', 'degreeCode': 203}], 'activeTimeDesc': '刚刚活跃', 'completeType': 0, 'resumeVideoInfo': None, 'multiGeekVideoResume4BossVO': None, 'highLightGeekResumeWords': None, 'enablePmq': False, 'geekFreeStatus': 0, 'hasJobCompetitive': 0, 'myGeekState': 0, 'hasItemBackGroundSurvey': 0, 'userFriendLabels': [], 'itemBannerVO': {'display': 0, 'buttonText': None, 'jumpUrl': None, 'text': None, 'subText': None, 'icon': None, 'type': 0}, 'showEyeBrow': False, 'geekInfoNull': False, 'recommendReason': None, 'potentialJobInterest': None, 'systemJob': False, 'closeInterview': False, 'filtered': False, 'isSystemJob': False, 'isCloseInterview': False, 'isFiltered': False} 已聊 {"code":0,"message":"Success","zpData":{"result":true}}
# 收到文字消息:您好，我仔细阅读了您发布的这个职位，和我自己比较匹配，希望能与您进一步沟通一下，期待您的回复
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 6, "messageRead": [{"userId": 50244003, "messageId": 533595626538, "readTime": 1702531170}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 6, "messageRead": [{"userId": 50244003, "messageId": 533595626538, "readTime": 1702531170}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 5, "messageSync": [{"clientMid": 1702531171135, "serverMid": 533595637101}], "domain": 1}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 4, "iqResponse": {"qid": 0, "query": "/message/suggest", "results": [{"key": "friend_source", "value": "0"}, {"key": "suggestions", "value": "[{\"label\":\"隐藏消息\",\"type\":0,\"value\":\"隐藏消息\"}]"}, {"key": "friendId", "value": "50244003"}, {"key": "msg_id", "value": "533595637101"}, {"key": "business_scene_type", "value": "7"}]}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 4, "iqResponse": {"qid": 0, "query": "/message/suggest", "results": [{"key": "friend_source", "value": "0"}, {"key": "suggestions", "value": "[{\"label\":\"隐藏消息\",\"type\":0,\"value\":\"隐藏消息\"}]"}, {"key": "friendId", "value": "50244003"}, {"key": "msg_id", "value": "533595637101"}, {"key": "business_scene_type", "value": "1"}]}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 4, "iqResponse": {"qid": 0, "query": "/message/suggest", "results": [{"key": "friend_source", "value": "0"}, {"key": "suggestions", "value": "[]"}, {"key": "friendId", "value": "50244003"}, {"key": "msg_id", "value": "533595637101"}, {"key": "business_scene_type", "value": "1"}]}}
# _on_message None <paho.mqtt.client.MQTTMessage object at 0x7fa5d66e3430>
# receive:  {"type": 6, "messageRead": [{"userId": 50244003, "messageId": 533595637101, "readTime": 1702531171}], "domain": 1}
